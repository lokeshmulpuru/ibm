# %% [markdown]
# # Coursera_Captsone Project

# %% [markdown]
# ### Welcome this project tells us about the "severity" caused by accidents in terms of human fatality, traffic delay, property damage, or any other type of accident bad impact.

# %%
import pandas as pd
import numpy as np

# %%
print(' Hello Capstone Project Course!')
# Out:
#  Hello Capstone Project Course!
